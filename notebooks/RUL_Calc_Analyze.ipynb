# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %% [markdown]
# ### Column names are assigned

# %%
columns = ["engine_id", "time_cycles", "opr_setting_1", "opr_setting_2", "opr_setting_3"] + [f's{i}' for i in range(1,22)]
df = pd.read_csv("train_FD001.txt", sep=' ', header=None, names=columns)
df
# Out:
#          engine_id  time_cycles  opr_setting_1  opr_setting_2  opr_setting_3  \
# 1   1      -0.0007      -0.0004          100.0         518.67         641.82
#     2       0.0019      -0.0003          100.0         518.67         642.15
#     3      -0.0043       0.0003          100.0         518.67         642.35
#     4       0.0007       0.0000          100.0         518.67         642.35
#     5      -0.0019      -0.0002          100.0         518.67         642.37
# ...            ...          ...            ...            ...            ...
# 100 196    -0.0004      -0.0003          100.0         518.67         643.49
#     197    -0.0016      -0.0005          100.0         518.67         643.54
#     198     0.0004       0.0000          100.0         518.67         643.42
#     199    -0.0011       0.0003          100.0         518.67         643.23
#     200    -0.0032      -0.0005          100.0         518.67         643.85
#
# ...

# %% [markdown]
# ### Finding maximum cycle for each number that they can reach and adding to table

# %%
max_cycles = df.groupby('engine_id')['time_cycles'].max().reset_index()
max_cycles.columns = ['engine_id', 'max_cycles']

df = pd.merge(df, max_cycles, on = 'engine_id', how = 'left')
df
# Out:
#        engine_id  time_cycles  opr_setting_1  opr_setting_2  opr_setting_3  \
# 0        -0.0007      -0.0004          100.0         518.67         641.82
# 1         0.0019      -0.0003          100.0         518.67         642.15
# 2        -0.0043       0.0003          100.0         518.67         642.35
# 3         0.0007       0.0000          100.0         518.67         642.35
# 4        -0.0019      -0.0002          100.0         518.67         642.37
# ...          ...          ...            ...            ...            ...
# 20626    -0.0004      -0.0003          100.0         518.67         643.49
# 20627    -0.0016      -0.0005          100.0         518.67         643.54
# 20628     0.0004       0.0000          100.0         518.67         643.42
# 20629    -0.0011       0.0003          100.0         518.67         643.23
# 20630    -0.0032      -0.0005          100.0         518.67         643.85
#
# ...

# %% [markdown]
# ### RUL(Remaining Useful Life) calculation for each engine

# %%
# RUL = (max cycle) - (current cycle)
df['RUL'] = df['max_cycles'] - df['time_cycles']

df = df.drop('max_cycles', axis = 1)
print(df[['engine_id', 'time_cycles', 'RUL']].head(10))
# Out:
#    engine_id  time_cycles     RUL
# 0    -0.0007      -0.0004  0.0010
# 1     0.0019      -0.0003  0.0009
# 2    -0.0043       0.0003  0.0002
# 3     0.0007       0.0000  0.0005
# 4    -0.0019      -0.0002  0.0007
# 5    -0.0043      -0.0001  0.0006
# 6     0.0010       0.0001  0.0004
# 7    -0.0034       0.0003  0.0003
# 8     0.0008       0.0001  0.0005
# 9    -0.0033       0.0001  0.0004
